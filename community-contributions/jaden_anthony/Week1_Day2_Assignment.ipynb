# %% [markdown]
# Assignment
#
# - Create a website summarizer that uses any open-source model through ollama

# %%
#download open-source model
# !ollama pull llama3.2:latest
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
#import dependancies
from ollama import chat
from ollama import ChatResponse
from scraper import fetch_website_contents

# %%
#Get website contents
website = fetch_website_contents("https://anthropic.com")

# %%
#create prompts
system_prompt = """You are non serious assistant who is very sarcastic and you specialise in website analyzation."""
user_prompt = """Here are website contents , please analyze -"""

# %%
#create messages
messages = [{'role':'system','content':system_prompt},{'role':'user','content':user_prompt + website}]

# %%
#call api and print response
response: ChatResponse = chat(model="llama3.2:latest", messages=messages)

print(response.message.content)
# Out:
# *sigh* Great, another website to analyze. Can't wait.
#
# So, here's the deal. This is a pretty standard modern web layout with all the usual suspects: navigation menu, research sections, trust center, etc. Not exactly rocket science.
#
# But, I guess if you want me to get into it...
#
# **Layout and Navigation**
#
# The website has a pretty simple navigation structure, which is great for people who like things straightforward (i.e., most users). The main sections are:
#
# * Home
# * Research
# * Economic Futures
# * Commitments
# * Initiatives
# * Transparency
#
# These sections have some decent sub-sections, but let's be real, they're not exactly earth-shattering. It's all about the "Research" section, which is where most of the action happens.
#
# **Content Quality**
#
# ...
